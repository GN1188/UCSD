# %%
import numpy as np


a = np.linalg.inv(np.array([[1,1,1],[1.5,5.75,2.60],[0,1,-1]]))
#print(a)
b = np.array([200,589.50,-20])
# res = a.dot(b)
print(res)
#print(res.sum())
# Out:
# [80. 50. 70.]
